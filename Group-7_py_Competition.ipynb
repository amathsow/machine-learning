# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('train.csv')

# %%
df
# Out:
#           country                                        description  \
# 0        Portugal  This is a fine rich balanced wine. It has ripe...
# 1          France  A solid, chunky wine, with a structure that is...
# 2          France  This is powerful and concentrated, with the hi...
# 3              US  Rich, ripe and oaky, this Petite Sirah charms ...
# 4              US  This wine is a unique in the state blend and f...
# 5           Spain  This brut nature is citric and bubbly on the p...
# 6          France  A ripe wine that has red-berry fruits, slices ...
# 7           Italy  From one of Sicily's most beautiful and promis...
# 8              US  This wine plays close to the edge of overripe-...
# 9           Italy  This basic Prosecco is perfectly quaffable tha...
# 10         France  A lovely Côtes-du-Rhône lookalike, this blend ...
# 11          Chile  Sort of sweet on the bouquet, with hints of le...
# 12         France  A big, rich style of Sancerre, but one that do...
# ...

# %%
df.head()
# Out:
#     country                                        description  \
# 0  Portugal  This is a fine rich balanced wine. It has ripe...
# 1    France  A solid, chunky wine, with a structure that is...
# 2    France  This is powerful and concentrated, with the hi...
# 3        US  Rich, ripe and oaky, this Petite Sirah charms ...
# 4        US  This wine is a unique in the state blend and f...
#
#                  designation     points  price    province  \
# 0         Vila Santa Reserva  88.870874   20.0  Alentejano
# 1                        NaN  88.041695   28.0    Bordeaux
# 2                        NaN  94.085021  130.0    Bordeaux
# 3          Thompson Vineyard  89.869797   34.0  California
# 4  McKinley Springs Vineyard  89.017651   24.0  Washington
#
#                region_1         region_2       taster_name  \
# 0                   NaN              NaN               NaN
# 1    Lalande de Pomerol              NaN               NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175000 entries, 0 to 174999
# Data columns (total 14 columns):
# country                  174953 non-null object
# description              175000 non-null object
# designation              122734 non-null object
# points                   175000 non-null float64
# price                    175000 non-null float64
# province                 174953 non-null object
# region_1                 146466 non-null object
# region_2                 75394 non-null object
# taster_name              65509 non-null object
# taster_twitter_handle    62190 non-null object
# title                    82189 non-null object
# variety                  174999 non-null object
# winery                   175000 non-null object
# id                       175000 non-null int64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 18.7+ MB

# %%
df.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery', 'id'],
#       dtype='object')

# %%
df.describe()
# Out:
#               points          price             id
# count  175000.000000  175000.000000  175000.000000
# mean       88.083987      34.304400   70684.047240
# std         3.157001      38.398146   41341.638798
# min        79.636128       4.000000       1.000000
# 25%        85.971283      16.000000   35020.000000
# 50%        87.981631      25.000000   70256.500000
# 75%        90.085631      40.000000  105550.250000
# max       100.220603    2500.000000  150929.000000

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery', 'id'],
#       dtype='object')

# %%
df.columns.value_counts().sum()
# Out:
# 14

# %%
df['country']
# Out:
# 0          Portugal
# 1            France
# 2            France
# 3                US
# 4                US
# 5             Spain
# 6            France
# 7             Italy
# 8                US
# 9             Italy
# 10           France
# 11            Chile
# 12           France
# 13               US
# 14               US
# 15        Argentina
# 16            Spain
# 17            Chile
# 18            Italy
# 19               US
# 20        Australia
# 21           Greece
# 22               US
# 23           France
# 24               US
# 25         Portugal
# 26        Australia
# 27               US
# 28            Italy
# 29               US
#             ...
# 174970    Argentina
# 174971        Italy
# 174972           US
# 174973    Argentina
# 174974           US
# 174975       France
# 174976           US
# 174977           US
# 174978           US
# 174979       France
# 174980        Italy
# 174981           US
# 174982      Austria
# 174983       France
# ...

# %%
df.describe()
# Out:
#               points          price             id
# count  175000.000000  175000.000000  175000.000000
# mean       88.083987      34.304400   70684.047240
# std         3.157001      38.398146   41341.638798
# min        79.636128       4.000000       1.000000
# 25%        85.971283      16.000000   35020.000000
# 50%        87.981631      25.000000   70256.500000
# 75%        90.085631      40.000000  105550.250000
# max       100.220603    2500.000000  150929.000000

# %%
#X=df[['points','id']]
#y=df['price']

# %%
#from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)
#from sklearn.linear_model import LinearRegression
#lm = LinearRegression()
#lm.fit(X_train,y_train)
#print(lm.intercept_)
#coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
#coeff_df
#predictions = lm.predict(X_test)
#plt.scatter(y_test,predictions)

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
#from sklearn.linear_model import LinearRegression

# %%
#lm = LinearRegression()

# %%
#lm.fit(X_train,y_train)

# %%
#print(lm.intercept_)

# %%
#coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
#coeff_df

# %%
#predictions = lm.predict(X_test)

# %%
#plt.scatter(y_test,predictions)

# %%
#sns.distplot((y_test-predictions),bins=50);

# %%
#from sklearn import metrics

# %%
#print('MAE:', metrics.mean_absolute_error(y_test, predictions))
#print('MSE:', metrics.mean_squared_error(y_test, predictions))
#print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

# %%
#from sklearn.ensemble import RandomForestRegressor

# %%
#rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)

# %%
#rf.fit(X_train, y_train)

# %%
#l = lm.predict(X_test)

# %%
#df2 = X_test.copy()
#df2['prediction'] = list(l)

# %%
#df2.head()

# %%
#from sklearn import metrics
#print('MAE:', metrics.mean_absolute_error(y_test, predictions))
#print('MSE:', metrics.mean_squared_error(y_test, predictions))
#print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

# %%
#df2.to_csv('Price_predicted')

# %%
#df.groupby('country')

# %%
(#df['points']==0).sum()
# Out:
#   File "<ipython-input-335-5a423545d9e7>", line 1
#     (#df['points']==0).sum()
#                             ^
# SyntaxError: unexpected EOF while parsing

# %%
#df.columns

# %%
#df[['description','price']]

# %%
#tips = sns.load_dataset('tips')

# %%
#tips.head()

# %%
#df.head()

# %%
#X = df[['points','id']]
#y = df['price']

# %%
#from sklearn.model_selection import train_test_split

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#from sklearn.preprocessing import StandardScaler

#sc = StandardScaler()
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# %%
#print(sc.mean_)

# %%
#sc.with_std

# %%
#from sklearn.decomposition import PCA

#pca = PCA()
#X_train = pca.fit_transform(X_train)
#X_test = pca.transform(X_test)

# %%
#list(X_test)

# %%
#from sklearn import metrics
#print('MAE:', metrics.mean_absolute_error(y_test, predictions))
#print('MSE:', metrics.mean_squared_error(y_test, predictions))
#print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

# %%
#df.isnull().any()

# %%
#df.dtypes

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.head()

# %%
#obj_df[obj_df.isnull().any(axis=1)]

# %%
#obj_df = obj_df.fillna({"region_2": "Central Coast"})

# %%
#obj_df = obj_df.fillna({"region_2": "Central Coast"})

# %%
#obj_df = obj_df.fillna({"region_2": "Central Coast"})

# %%
#obj_df = obj_df.fillna({"region_1": "Napa Valley "})
#obj_df =obj_df.fillna({"region_2": "Central Coast"})
#obj_df = obj_df.fillna({"country": "US"})
#obj_df = obj_df.fillna({"designation": "Reserve"})
#obj_df =obj_df.fillna({"province": "California"})
#obj_df = obj_df.fillna({"taster_name": "Roger Voss"})
#obj_df = obj_df.fillna({"taster_twitter_handle": "@vossroger"})
#obj_df = obj_df.fillna({"title": "Gloria Ferrer NV Sonoma Brut Sparkling (Sonoma County) "})
#obj_df = obj_df.fillna({"variety": "PINOT NOIR   "})
#obj_df = obj_df.fillna({"winery": "Williams Selyem "})

# %%
obj_df["region_1"] = obj_df["region_1"].astype('category').cat.codes
#obj_df.dtypes
#obj_df["region_1_cat"] = obj_df["region_1"].cat.codes
#obj_df['region_1_cat'].value_counts()

obj_df["region_2"] = obj_df["region_2"].astype('category').cat.codes
#obj_df.dtypes
#obj_df["region_2_cat"] = obj_df["region_2"].cat.codes
#obj_df['region_2_cat'].value_counts()

obj_df["country"] = obj_df["country"].astype('category').cat.codes
#obj_df.dtypes
#obj_df["country_cat"] = obj_df["country"].cat.codes
#obj_df['country_cat'].value_counts()

obj_df["description"] = obj_df["description"].astype('category').cat.codes
#obj_df.dtypes
#obj_df["description_cat"] = obj_df["description"].cat.codes
#obj_df['description_cat'].value_counts()


obj_df["designation"] = obj_df["designation"].astype('category').cat.codes
#obj_df.dtypes
#obj_df["designation_cat"] = obj_df["designation"].cat.codes
#obj_df['designation_cat'].value_counts()


obj_df["province"] = obj_df["province"].astype('category').cat.codes
#obj_df.dtypes
#obj_df["province_cat"] = obj_df["province"].cat.codes
#obj_df['province_cat'].value_counts()


obj_df["taster_name"] = obj_df["taster_name"].astype('category').cat.codes
#obj_df.dtypes
#obj_df["taster_name_cat"] = obj_df["taster_name"].cat.codes
#obj_df['taster_name_cat'].value_counts()


obj_df["taster_twitter_handle"] = obj_df["taster_twitter_handle"].astype('category').cat.codes
#obj_df.dtypes
#obj_df["taster_twitter_handle_cat"] = obj_df["taster_twitter_handle"].cat.codes
#obj_df['taster_twitter_handle_cat'].value_counts()


obj_df["title"] = obj_df["title"].astype('category').cat.codes
#obj_df.dtypes
#obj_df["title_cat"] = obj_df["title"].cat.codes
#obj_df['title_cat'].value_counts()


obj_df["variety"] = obj_df["variety"].astype('category').cat.codes
#obj_df.dtypes
#obj_df["variety_cat"] = obj_df["variety"].cat.codes
#obj_df['variety_cat'].value_counts()


obj_df["winery"] = obj_df["winery"].astype('category').cat.codes
#obj_df.dtypes
#obj_df["winery_cat"] = obj_df["winery"].cat.codes
#obj_df['winery_cat'].value_counts()

# %%
obj_df.info()

# %%
obj_df['id']=df['id']
obj_df['points']=df['points']
obj_df['price']=df['price']
#X=obj_df[['points','region_2_cat','region_1_cat','country_cat','description_cat','designation_cat','province_cat','taster_name_cat','taster_twitter_handle_cat','title_cat','variety_cat','winery_cat']]
#y=obj_df['price']
#obj_df

# %%
obj_df

# %%
obj_df['region_2_cat'].value_counts()

# %%
#from xgboost import XGBClassifier
import xgboost as xgb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-351-01e9a153b709> in <module>()
#       1 #from xgboost import XGBClassifier
# ----> 2 import xgboost as xgb
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
X=obj_df[['points','region_2_cat','country_fcat','province_cat','taster_name_cat','taster_twitter_handle_cat','title_cat']]
y=obj_df['price']
obj_df
# Out:
#         country  description  designation  province  region_1  region_2  \
# 0            32        98899        35911         8         0         1
# 1            14        10809           -1        38       573         1
# 2            14       104319           -1        38       967         1
# 3            42        68273        33838        53       998         1
# 4            42       112607        21691       454       528         3
# 5            39        94272         4632        66       192         1
# 6            14         9478         9055        38       127         1
# 7            21        39898         2453       365      1024         1
# 8            42       113760           -1        53       942        13
# 9            21        92639        19307       425       871         1
# 10           14         7197        29179       330       335         1
# 11            8        76479           -1        98         0         1
# ...

# %%
#X=obj_df[['points','id']]
#y=obj_df['price']
#obj_df

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)

# %%
xg_reg.fit(X_train,y_train)

# %%
preds = xg_reg.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-338-5718c711d611> in <module>()
# ----> 1 preds = xg_reg.predict(X_test)
#
# NameError: name 'xg_reg' is not defined

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-337-2940dc10b094> in <module>()
#       1 from sklearn.metrics import mean_squared_error
# ----> 2 rmse = np.sqrt(mean_squared_error(y_test, preds))
#       3 print("RMSE: %f" % (rmse))
#
# NameError: name 'preds' is not defined

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print(lm.intercept_)
# Out:
# -448.5685305471551

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                            Coefficient
# points                        5.417968
# region_2_cat                  0.114518
# country_cat                  -0.063010
# province_cat                 -0.014167
# taster_name_cat               0.680999
# taster_twitter_handle_cat     0.037882
# title_cat                     0.000005

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.distplot((y_test-predictions),bins=50);

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 16.698616710095706
# MSE: 1281.0888675265526
# RMSE: 35.79230179139856

# %%
obj_df.describe()
# Out:
#         region_1_cat   region_2_cat    country_cat  description_cat  \
# count  175000.000000  175000.000000  175000.000000    175000.000000
# mean      542.258303       3.428960      29.138589     61511.780863
# std       425.555496       4.508153      14.438695     35755.550053
# min        -1.000000       0.000000       0.000000         0.000000
# 25%       122.000000       1.000000      14.000000     30571.750000
# 50%       545.000000       1.000000      39.000000     61590.000000
# 75%       941.000000       3.000000      42.000000     92174.000000
# max      1277.000000      17.000000      44.000000    123810.000000
#
#        designation_cat   province_cat  taster_name_cat  \
# count    175000.000000  175000.000000    175000.000000
# mean      13503.523200     199.244863        13.845183
# std       12616.670954     153.464225         3.099849
# min          -1.000000       0.000000         0.000000
# 25%          -1.000000      53.000000        15.000000
# ...

# %%
obj_df
# Out:
#           country                                        description  \
# 0        Portugal  This is a fine rich balanced wine. It has ripe...
# 1          France  A solid, chunky wine, with a structure that is...
# 2          France  This is powerful and concentrated, with the hi...
# 3              US  Rich, ripe and oaky, this Petite Sirah charms ...
# 4              US  This wine is a unique in the state blend and f...
# 5           Spain  This brut nature is citric and bubbly on the p...
# 6          France  A ripe wine that has red-berry fruits, slices ...
# 7           Italy  From one of Sicily's most beautiful and promis...
# 8              US  This wine plays close to the edge of overripe-...
# 9           Italy  This basic Prosecco is perfectly quaffable tha...
# 10         France  A lovely Côtes-du-Rhône lookalike, this blend ...
# 11          Chile  Sort of sweet on the bouquet, with hints of le...
# 12         France  A big, rich style of Sancerre, but one that do...
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
data = pd.read_csv('train.csv')
X = data.iloc[:,0:20]  #independent columns
y = data.iloc[:,-1]    #target column i.e price range#apply SelectKBest class to extract top 10 best features
#bestfeatures = SelectKBest(score_func=chi2, k=10)
#fit = bestfeatures.fit(X,y)
#dfscores = pd.DataFrame(fit.scores_)
#dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
#featureScores = pd.concat([dfcolumns,dfscores],axis=1)
#featureScores.columns = ['Specs','Score']  #naming the dataframe columns
#print(featureScores.nlargest(10,'Score'))  #print 10 best features

# %%
bestfeatures = SelectKBest(score_func=chi2, k=10)

# %%
fit = bestfeatures.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-0a1a3e393f5e> in <module>()
# ----> 1 fit = bestfeatures.fit(X,y)
#
# /usr/lib/python3/dist-packages/sklearn/feature_selection/univariate_selection.py in fit(self, X, y)
#     339         self : object
#     340         """
# --> 341         X, y = check_X_y(X, y, ['csr', 'csc'], multi_output=True)
#     342
#     343         if not callable(self.score_func):
#
# /usr/lib/python3/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
# ...
